# %%
import pandas as pd
from sqlalchemy import create_engine


engine = create_engine("mysql+pymysql://root:Strength#123@localhost/DS_db")


with engine.connect() as conn:
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
# %load_ext sql
# %sql mysql+pymysql://root:Strength%23123@localhost/DS_db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'mysql+pymysql://root:***@localhost/DS_db'

# %% [markdown]
# <h3 style = "color:green">1. SELECT

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">
# The 'SELECT' command is used to retrieve data from one or more tables in a database.<br>
# Basic syntax: SELECT col1, col2 FROM database_name.table_name;
# </div>

# %%
# %%sql
# SELECT *
# FROM DS_db.employees;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/DS_db'
# 10 rows affected.
# +----+----------------+-------------+----------+-----+------------+
# | id |      name      |  department |  salary  | age | join_date  |
# +----+----------------+-------------+----------+-----+------------+
# | 1  |  Asha Sharma   | Engineering | 75000.00 |  28 | 2021-03-15 |
# | 2  |  Rohan Mehta   |  Marketing  | 52000.00 |  35 | 2019-07-01 |
# | 3  |  Priya Thapa   | Engineering | 81000.00 |  30 | 2020-11-20 |
# | 4  |   Bikash Rai   |      HR     | 45000.00 |  26 | 2022-01-10 |
# | 5  |   Sita Karki   |  Marketing  | 60000.00 |  32 | 2018-05-25 |
# | 6  | Aman Shrestha  | Engineering | 90000.00 |  34 | 2017-09-30 |
# | 7  |  Nisha Poudel  |      HR     | 47000.00 |  27 | 2023-02-14 |
# | 8  | Suraj Adhikari |  Marketing  | 55000.00 |  29 | 2021-08-08 |
# | 9  |  Deepa Gurung  | Engineering | 78000.00 |  31 | 2020-04-17 |
# | 10 |  Kiran Tamang  |      HR     | 43000.00 |  24 | 2023-06-01 |
# +----+----------------+-------------+----------+-----+------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# SELECT name
# FROM DS_db.employees;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/DS_db'
# 10 rows affected.
# +----------------+
# |      name      |
# +----------------+
# |  Asha Sharma   |
# |  Rohan Mehta   |
# |  Priya Thapa   |
# |   Bikash Rai   |
# |   Sita Karki   |
# | Aman Shrestha  |
# |  Nisha Poudel  |
# | Suraj Adhikari |
# |  Deepa Gurung  |
# |  Kiran Tamang  |
# +----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT
# name,
# department,
# age
# FROM DS_db.employees;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/DS_db'
# 10 rows affected.
# +----------------+-------------+-----+
# |      name      |  department | age |
# +----------------+-------------+-----+
# |  Asha Sharma   | Engineering |  28 |
# |  Rohan Mehta   |  Marketing  |  35 |
# |  Priya Thapa   | Engineering |  30 |
# |   Bikash Rai   |      HR     |  26 |
# |   Sita Karki   |  Marketing  |  32 |
# | Aman Shrestha  | Engineering |  34 |
# |  Nisha Poudel  |      HR     |  27 |
# | Suraj Adhikari |  Marketing  |  29 |
# |  Deepa Gurung  | Engineering |  31 |
# |  Kiran Tamang  |      HR     |  24 |
# +----------------+-------------+-----+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# SELECT age+10
# FROM employees;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/DS_db'
# 10 rows affected.
# +--------+
# | age+10 |
# +--------+
# |   38   |
# |   45   |
# |   40   |
# |   36   |
# |   42   |
# |   44   |
# |   37   |
# |   39   |
# |   41   |
# |   34   |
# +--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT DISTINCT age
# FROM employees;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/DS_db'
# 11 rows affected.
# +-----+
# | age |
# +-----+
# |  28 |
# |  35 |
# |  30 |
# |  26 |
# |  32 |
# |  34 |
# |  27 |
# |  29 |
# |  31 |
# |  24 |
# +-----+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT DISTINCT department, age
# FROM employees;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/DS_db'
# 11 rows affected.
# +-------------+-----+
# |  department | age |
# +-------------+-----+
# | Engineering |  28 |
# |  Marketing  |  35 |
# | Engineering |  30 |
# |      HR     |  26 |
# |  Marketing  |  32 |
# | Engineering |  34 |
# |      HR     |  27 |
# |  Marketing  |  29 |
# | Engineering |  31 |
# |      HR     |  24 |
# +-------------+-----+
# Truncated to displaylimit of 10.
