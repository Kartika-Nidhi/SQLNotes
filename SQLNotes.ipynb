# %%
import pandas as pd
from sqlalchemy import create_engine


engine = create_engine("mysql+pymysql://root:Strength#123@localhost/DS_db")


with engine.connect() as conn:
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
data = pd.read_sql("SELECT * FROM employees;", engine)

data
# Out:
#    id            name   department   salary  age   join_date
# 0   1     Asha Sharma  Engineering  75000.0   28  2021-03-15
# 1   2     Rohan Mehta    Marketing  52000.0   35  2019-07-01
# 2   3     Priya Thapa  Engineering  81000.0   30  2020-11-20
# 3   4      Bikash Rai           HR  45000.0   26  2022-01-10
# 4   5      Sita Karki    Marketing  60000.0   32  2018-05-25
# 5   6   Aman Shrestha  Engineering  90000.0   34  2017-09-30
# 6   7    Nisha Poudel           HR  47000.0   27  2023-02-14
# 7   8  Suraj Adhikari    Marketing  55000.0   29  2021-08-08
# 8   9    Deepa Gurung  Engineering  78000.0   31  2020-04-17
# 9  10    Kiran Tamang           HR  43000.0   24  2023-06-01
